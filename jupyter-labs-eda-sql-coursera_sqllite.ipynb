# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
# <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">Spacex DataSet</a>

# %% [markdown]
# ### Store the dataset in database table
#
# **it is highly recommended to manually load the table using the database console LOAD tool in DB2**.
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload.png">
#
# Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the  dataset, Next create a New Table, and then follow the steps on-screen instructions to load the data. Name the new table as follows:
#
# **SPACEXDATASET**
#
# **Follow these steps while using old DB2 UI which is having Open Console Screen**
#
# **Note:While loading Spacex dataset, ensure that detect datatypes is disabled. Later click on the pencil icon(edit option).**
#
# 1.  Change the Date Format by manually typing DD-MM-YYYY and timestamp format as DD-MM-YYYY HH\:MM:SS
#
# 2.  Change the PAYLOAD_MASS\_\_KG\_  datatype  to INTEGER.
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload2.png">

# %% [markdown]
# **Changes to be considered when having DB2 instance with the new UI having Go to UI screen**
#
# *   Refer to this insruction in this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sign%20up%20for%20IBM%20Cloud%20-%20Create%20Db2%20service%20instance%20-%20Get%20started%20with%20the%20Db2%20console/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">link</a> for viewing  the new  Go to UI screen.
#
# *   Later click on **Data link(below SQL)**  in the Go to UI screen  and click on **Load Data** tab.
#
# *   Later browse for the downloaded spacex file.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/browsefile.png" width="800"/>
#
# *   Once done select the schema andload the file.
#
#  <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload3.png" width="800"/>

# %%
# !pip install sqlalchemy==1.3.9
# Out:
# Collecting sqlalchemy==1.3.9
#   Downloading SQLAlchemy-1.3.9.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 3.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp39-cp39-macosx_11_0_arm64.whl size=1142927 sha256=513fbe9123e5f62d7306cc2bf97a44beee657d63b9862f350ee7bfc4341ffb00
#   Stored in directory: /Users/federicoguzzo/Library/Caches/pip/wheels/5b/43/0d/de1699809f9e6aaa54a97275298fa07075cb19acc557b18955
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
# Successfully installed sqlalchemy-1.3.9

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2305, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2303     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2304 with self.builtin_trap:
# -> 2305     result = fn(*args, **kwargs)
#    2306 return result
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/magics/extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/extensions.py:76, in ExtensionManager.load_extension(self, module_str)
#      69 """Load an IPython extension by its module name.
#      70
#      71 Returns the string "already loaded" if the extension is already loaded,
#      72 "no load function" if the module doesn't have a load_ipython_extension
#      73 function, or None if it succeeded.
#      74 """
#      75 try:
# ---> 76     return self._load_extension(module_str)
#      77 except ModuleNotFoundError:
#      78     if module_str in BUILTINS_EXTS:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/extensions.py:92, in ExtensionManager._load_extension(self, module_str)
#      90 if module_str not in sys.modules:
#      91     with prepended_to_syspath(self.ipython_extension_dir):
# ---> 92         mod = import_module(module_str)
#      93         if mod.__file__.startswith(self.ipython_extension_dir):
#      94             print(("Loading extensions from {dir} is deprecated. "
#      95                    "We recommend managing extensions like any "
#      96                    "other Python packages, in site-packages.").format(
#      97                   dir=compress_user(self.ipython_extension_dir)))
#
# File ~/opt/anaconda3/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'sql'

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5
# Out:
#   error: subprocess-exited-with-error
#
#   × Building wheel for pandas (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1160 lines of output]
#       <string>:45: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       <string>:454: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-39
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas
#       copying pandas/conftest.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas
#       copying pandas/_typing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas
#       copying pandas/_version.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas
#       copying pandas/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas
#       copying pandas/_testing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas
#       copying pandas/testing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/compat
#       copying pandas/compat/_optional.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/compat
#       copying pandas/compat/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/compat
#       copying pandas/compat/chainmap.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/compat
#       copying pandas/compat/pickle_compat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/compat
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/accessor.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/nanops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/missing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/aggregation.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/algorithms.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/resample.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/index.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/construction.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/config_init.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/generic.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/series.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/sorting.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/indexers.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/frame.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/shared_docs.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/indexing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/base.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/strings.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       copying pandas/core/apply.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/_depr_module.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/_test_decorators.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/_validators.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/_print_versions.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/_decorators.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/_doctools.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/testing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/_exceptions.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       copying pandas/util/_tester.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/util
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/orc.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/feather_format.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/parquet.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/pytables.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/html.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/clipboards.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/parsers.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/date_converters.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/pickle.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/sql.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/stata.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/gbq.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       copying pandas/io/spss.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/offsets.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/frequencies.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/holiday.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tseries
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_optional_dependency.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_expressions.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_register_accessor.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_downstream.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_errors.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_sorting.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_join.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_aggregation.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_lib.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_nanops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_take.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_algos.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_multilevel.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_strings.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/_libs
#       copying pandas/_libs/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/_libs
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_core.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_misc.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/arrays
#       copying pandas/arrays/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/arrays
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/api
#       copying pandas/api/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/api
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/errors
#       copying pandas/errors/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/errors
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/_config
#       copying pandas/_config/config.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/_config
#       copying pandas/_config/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/_config
#       copying pandas/_config/display.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/_config
#       copying pandas/_config/localization.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/_config
#       copying pandas/_config/dates.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/_config
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/compat/numpy
#       copying pandas/compat/numpy/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/compat/numpy
#       copying pandas/compat/numpy/function.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/compat/numpy
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/tile.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/merge.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/concat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/util.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/reshape.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/melt.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/pivot.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/reshape
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/timedeltas.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/datetimes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/times.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/numeric.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/tools
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/util
#       copying pandas/core/util/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/util
#       copying pandas/core/util/hashing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/util
#       copying pandas/core/util/numba_.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/util
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/array_algos
#       copying pandas/core/array_algos/transforms.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/array_algos
#       copying pandas/core/array_algos/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/array_algos
#       copying pandas/core/array_algos/masked_reductions.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/array_algos
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/cast.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/missing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/concat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/generic.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/dtypes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/inference.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/base.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/dtypes
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/categorical.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/generic.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/ops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/grouper.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/groupby.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/base.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/groupby
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/concat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/construction.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/ops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/blocks.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/managers.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/internals
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/parsing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/check.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/align.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/pytables.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/engines.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/expressions.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/ops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/eval.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/scope.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/expr.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/computation
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/window
#       copying pandas/core/window/ewm.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/window
#       copying pandas/core/window/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/window
#       copying pandas/core/window/rolling.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/window
#       copying pandas/core/window/indexers.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/window
#       copying pandas/core/window/common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/window
#       copying pandas/core/window/numba_.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/window
#       copying pandas/core/window/expanding.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/window
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/categorical.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/_arrow_utils.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/interval.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/timedeltas.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/datetimes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/string_.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/numpy_.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/_ranges.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/boolean.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/integer.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/masked.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/period.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/datetimelike.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/base.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/_mixins.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/array_ops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/roperator.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/missing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/methods.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/dispatch.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/invalid.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/docstrings.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/mask_ops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       copying pandas/core/ops/common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/ops
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/sparse
#       copying pandas/core/sparse/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/sparse
#       copying pandas/core/sparse/api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/sparse
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/accessors.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/interval.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/timedeltas.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/range.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/datetimes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/multi.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/period.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/frozen.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/extension.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/numeric.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/datetimelike.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/base.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/category.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/indexes
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/accessor.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/scipy_sparse.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/dtype.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/array.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/core/arrays/sparse
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/console.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/style.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/html.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/format.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/excel.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/css.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/csvs.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/info.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/latex.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/printing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_openpyxl.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_base.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_xlrd.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_pyxlsb.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_odswriter.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_util.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_odfreader.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_xlwt.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       copying pandas/io/excel/_xlsxwriter.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/excel
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/io/json
#       copying pandas/io/json/_json.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/json
#       copying pandas/io/json/_normalize.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/json
#       copying pandas/io/json/_table_schema.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/json
#       copying pandas/io/json/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/json
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/sas7bdat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/sas_constants.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/sasreader.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/sas_xport.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/sas
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/io/clipboard
#       copying pandas/io/clipboard/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/clipboard
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_block_internals.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_alter_axes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_period.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/conftest.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_reductions.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_timeseries.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_constructors.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_missing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_cumulative.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_timezones.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_operators.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_subclass.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_analytics.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_io.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_datetime_values.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_internals.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_repr.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_ufunc.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_validate.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_duplicates.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_arithmetic.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_combine_concat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_dtypes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/series
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot_multilevel.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_cut.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_get_dummies.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_union_categoricals.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_qcut.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_util.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_melt.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_concat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_crosstab.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/reshape
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/tools
#       copying pandas/tests/tools/test_to_time.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/tools
#       copying pandas/tests/tools/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/tools
#       copying pandas/tests/tools/test_to_timedelta.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/tools
#       copying pandas/tests/tools/test_to_datetime.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/tools
#       copying pandas/tests/tools/test_to_numeric.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/tools
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_external_block.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_period.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/conftest.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_sparse.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_string.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_categorical.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_boolean.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_interval.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_datetime.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_integer.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_numpy.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/extension
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/conftest.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_resampler_grouper.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_timedelta.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_deprecated.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_period_index.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_datetime_index.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_base.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_time_grouper.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_resample_api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/resample
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_nonkeyword_arguments.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_validate_args_and_kwargs.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_series_equal.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/conftest.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_safe_import.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_frame_equal.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_show_versions.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_interval_array_equal.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_util.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_index_equal.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_validate_args.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_validate_kwargs.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_categorical_equal.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_numpy_array_equal.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_extension_array_equal.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_deprecate.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_hashing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_produces_warning.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_numba.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_doc.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_kwarg.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_almost_equal.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/util
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/config
#       copying pandas/tests/config/test_localization.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/config
#       copying pandas/tests/config/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/config
#       copying pandas/tests/config/test_config.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/config
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_parquet.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_fsspec.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_compression.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_date_converters.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/conftest.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_pickle.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_orc.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_clipboard.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_stata.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_html.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_gcs.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_sql.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_gbq.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_feather.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_spss.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/generate_legacy_storage_files.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_s3.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/io
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/tseries
#       copying pandas/tests/tseries/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/tseries
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_block_internals.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_alter_axes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_period.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/conftest.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_axis_select_reindex.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_timeseries.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_constructors.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_missing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_query_eval.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_join.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_cumulative.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_timezones.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_sort_values_level_as_str.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_operators.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_subclass.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_reshape.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_analytics.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_repr_info.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_nonunique_indexes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_validate.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_api.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_arithmetic.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_combine_concat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_dtypes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       copying pandas/tests/frame/test_to_csv.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/frame
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_inference.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_missing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/dtypes
#       copying pandas/tests/dtypes/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_generic.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_concat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_dtypes.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/dtypes
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_timegrouper.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_grouping.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_counting.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_value_counts.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_groupby_subclass.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/conftest.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_nth.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_nunique.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_sample.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_size.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_categorical.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_bin_groupby.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_apply.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_allowlist.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_quantile.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_apply_mutate.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_groupby_dropna.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_function.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_groupby.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_pipe.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_filters.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_rank.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       copying pandas/tests/groupby/test_index_as_string.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/groupby
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/internals
#       copying pandas/tests/internals/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/internals
#       copying pandas/tests/internals/test_internals.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/internals
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/computation
#       copying pandas/tests/computation/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/computation
#       copying pandas/tests/computation/test_compat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/computation
#       copying pandas/tests/computation/test_eval.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/computation
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/plotting
#       copying pandas/tests/plotting/test_backend.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/plotting
#       copying pandas/tests/plotting/test_common.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/plotting
#       copying pandas/tests/plotting/test_frame.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/plotting
#       copying pandas/tests/plotting/test_misc.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/plotting
#       copying pandas/tests/plotting/test_boxplot_method.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/plotting
#       copying pandas/tests/plotting/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/plotting
# ...
#       copying pandas/tests/indexes/multi/test_astype.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_formats.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_setops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_take.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_equivalence.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_get_set.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_compat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_monotonic.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_isin.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_drop.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_duplicates.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_partial_indexing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_lexsort.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_reindex.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/multi
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_period.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_searchsorted.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_shift.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_constructors.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_join.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_factorize.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_to_timestamp.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_scalar_compat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_indexing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_astype.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_formats.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_setops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_partial_slicing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_monotonic.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_fillna.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_ops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_tools.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_asfreq.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_period_range.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/period
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_constructors.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_indexing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_astype.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_formats.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_category.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_fillna.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_map.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_reindex.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/categorical
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/numeric
#       copying pandas/tests/indexes/numeric/test_join.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/numeric
#       copying pandas/tests/indexes/numeric/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/numeric
#       copying pandas/tests/indexes/numeric/test_indexing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/numeric
#       copying pandas/tests/indexes/numeric/test_astype.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/numeric
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_shift.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_misc.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_insert.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_constructors.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_pickle.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_to_period.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_join.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_date_range.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_timezones.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_datetimelike.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_snap.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_scalar_compat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_indexing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_delete.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_astype.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_formats.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_setops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_datetime.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_partial_slicing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_fillna.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_map.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_ops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/datetimes
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_searchsorted.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_shift.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_insert.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_constructors.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_join.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_timedelta.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_scalar_compat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_indexing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_delete.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_astype.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_formats.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_setops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_partial_slicing.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_fillna.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_ops.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_timedelta_range.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/_libs/window
#       copying pandas/_libs/window/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/_libs/window
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/_libs/tslibs
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/misc.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/hist.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/compat.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/boxplot.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/style.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/tools.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/converter.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/core.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/timeseries.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/plotting/_matplotlib
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/api/indexers
#       copying pandas/api/indexers/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/api/indexers
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/api/types
#       copying pandas/api/types/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/api/types
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/api/extensions
#       copying pandas/api/extensions/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/pandas/api/extensions
#       creating build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats/templates
#       copying pandas/io/formats/templates/html.tpl -> build/lib.macosx-11.1-arm64-cpython-39/pandas/io/formats/templates
#       UPDATING build/lib.macosx-11.1-arm64-cpython-39/pandas/_version.py
#       set build/lib.macosx-11.1-arm64-cpython-39/pandas/_version.py to '1.1.5'
#       running build_ext
#       building 'pandas._libs.algos' extension
#       creating build/temp.macosx-11.1-arm64-cpython-39
#       creating build/temp.macosx-11.1-arm64-cpython-39/pandas
#       creating build/temp.macosx-11.1-arm64-cpython-39/pandas/_libs
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/federicoguzzo/opt/anaconda3/include -arch arm64 -I/Users/federicoguzzo/opt/anaconda3/include -fPIC -O2 -isystem /Users/federicoguzzo/opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I./pandas/_libs -Ipandas/_libs/src/klib -I/private/var/folders/2h/w_9gp5dd3d13tpb2vc5xmqt80000gn/T/pip-build-env-h2l9wnzp/overlay/lib/python3.9/site-packages/numpy/core/include -I/Users/federicoguzzo/opt/anaconda3/include/python3.9 -c pandas/_libs/algos.c -o build/temp.macosx-11.1-arm64-cpython-39/pandas/_libs/algos.o -Wno-error=unreachable-code
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pandas
# ERROR: Could not build wheels for pandas, which is required to install pyproject.toml-based projects

# %%
# %sql sqlite:///my_data1.db
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
# For Example "Landing_Outcome"**
#
# ### Task 1
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql select distinct(LAUNCH_SITE) from SPACEXTBL
# Out:
# UsageError: Line magic function `%sql` not found.

# %% [markdown]
# ### Task 2
#
# ##### Display 5 records where launch sites begin with the string 'CCA'

# %% [markdown]
# ### Task 3
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %% [markdown]
# ### Task 4
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
# *Hint:Use min function*

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %% [markdown]
# ### Task 7
#
# ##### List the total number of successful and failure mission outcomes

# %% [markdown]
# ### Task 8
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %% [markdown]
# ### Task 9
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 4, 2) as month to get the months and substr(Date,7,4)='2015' for year.**

# %% [markdown]
# ### Task 10
#
# ##### Rank the  count of  successful landing_outcomes between the date 04-06-2010 and 20-03-2017 in descending order.

# %% [markdown]
# ### Reference Links
#
# *   <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01&origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *   <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01&origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *   <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01&origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *   <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
#
# | Date       | Version | Changed by    | Change Description        |
# | ---------- | ------- | ------------- | ------------------------- |
# | 2021-07-09 | 0.2     | Lakshmi Holla | Changes made in magic sql |
# | 2021-05-20 | 0.1     | Lakshmi Holla | Created Initial Version   |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
